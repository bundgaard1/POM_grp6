# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
counter = 0
ctl_q = 1
ctl_q_target = 2
env_q = 3
env_q_vel = 4
motor_tourqe = 5

# %%
datafile = "6.txt"

input6 = np.loadtxt(datafile,dtype='f', delimiter=' ')
plt.plot(input[:,env_q], label="Robot arm angle")
plt.plot(input[:,ctl_q_target], label ="Target angle")
plt.plot(0,1, label = "$K_d=2$")

plt.legend()

# %%
datafile = "7.txt"

input7 = np.loadtxt(datafile,dtype='f', delimiter=' ')
plt.plot(input7[:,ctl_q_target], label ="Target angle")
plt.plot(input6[:,env_q], label="Robot arm angle, $K_d=2$")
plt.plot(input7[:,env_q], label="Robot arm angle, $K_d=1$")
plt.legend()

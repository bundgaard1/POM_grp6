# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
time = 0
env_q= 1
env_q_vel = 2
ctl_q_target = 3
ctl_q = 4
motor_tourqe = 5

# %%
Scenario = 3
datafile = f"{Scenario}.txt"

input = np.loadtxt(datafile,dtype='f', delimiter=' ')


plt.scatter(input[:,time], input[:,env_q], label="Robot arm angle")
#plt.plot(input[:,time], input[:,env_q_vel], label="Robot arm angle velocity")
plt.xlabel("time, s")
plt.ylabel("Angle, rad / Angle velocity, rad/s")
plt.title(f"Scenario: {Scenario} - $K_d = {3}, K_p = {0.1}$")
plt.legend()

# %%
Secnario = 1
datafile = f"{Secnario}.txt"

input = np.loadtxt(datafile,dtype='f', delimiter=' ')
plt.scatter(input[:,time], input[:,env_q], label="Robot arm _q")
#plt.title(f"Scenario: {4} - $K_d = {2}, K_p = {0.}$")
#plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
time = 0
ctl_q = 1
ctl_q_target = 2
env_q = 3
env_q_vel = 4
motor_tourqe = 5

# %%
Secnario = 3
datafile = f"{Secnario}.txt"

input = np.loadtxt(datafile,dtype='f', delimiter=' ')
plt.plot(input[:,time], input[:,env_q], label="Robot arm angle")
plt.plot(input[:,time], input[:,ctl_q_target], label ="Target angle")
plt.title(f"Scenario: {2} - $K_d = {0.2}, K_p = {0.05}$")
plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
counter = 0
ctl_q = 1
ctl_q_target = 2
env_q = 3
env_q_vel = 4
motor_tourqe = 5

# %%
datafile = "5.txt"

input = np.loadtxt(datafile,dtype='f', delimiter=' ')
plt.plot(input[:,env_q], label="Robot arm angle")
plt.plot(input[:,ctl_q], label="Contoller arm angle perspective")
plt.plot(input[:,ctl_q_target], label ="Target angle")
plt.plot(input[:,motor_tourqe], label="Motor tourqe")
plt.legend()
